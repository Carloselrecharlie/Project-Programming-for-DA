# %% [markdown]
# #### <div style="text-align: right"> By Carlos Montes </div>
# <div style="text-align: right"> December 2018 </div>
#
#
# In this notebook I am going to look at a real phenomenon of my choice: a health study with a sample of population related to heart disease. A heart attack is usually caused by the buildup of plaque in the coronary arteries. The plaque builds up over time to eventually slow or completely block blood flow to the heart muscle. What matters now is the variables that condition the appearance of this health issue. It's worth mentioning that there may not be a most definitive one by itself, it seems to be just a question of balance between themselves. Anyways they are approximately graded from greater to lesser likelihood of importance.
#
# For the purpose of this exercise I will synthesise a data set with the values of all the risk factor which affect the heart attack. Half of the samples represent males and the other half woman being 400 in total.
#
# ## 1) Age
# As we get older, our risk of a heart attack goes up. Men age 45 or older and women age 55 or older are more likely to have a heart attack than are younger men and women [[1]](https://www.mayoclinic.org/diseases-conditions/heart-attack/symptoms-causes/syc-20373106) This is a discrete numerical variable and for the synthetised data set I am going to generate a sample of 400 people. The age will be presented in years with integer values and following a uniform distribution to garantee that all the age ranges will be equally represented.

# %%
# First of all I will import all the libraries I will use in this file
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# python magic command to make sure all the plots are displayed properly:
# %matplotlib inline
# Create a 400 people age between 20 and 70 years old
age = np.random.randint(20,70,size=400)
age
# Out:
# array([61, 29, 24, 65, 61, 62, 61, 47, 55, 38, 43, 43, 31, 35, 43, 49, 41,
#        56, 40, 57, 32, 50, 67, 40, 22, 64, 57, 32, 55, 69, 38, 57, 20, 48,
#        25, 29, 68, 49, 50, 57, 47, 54, 59, 28, 34, 55, 66, 40, 50, 55, 27,
#        25, 48, 21, 60, 53, 25, 41, 49, 40, 56, 44, 64, 32, 42, 49, 22, 35,
#        41, 53, 31, 30, 52, 65, 41, 20, 65, 63, 48, 53, 67, 52, 48, 54, 30,
#        22, 34, 31, 55, 41, 62, 38, 66, 40, 55, 62, 21, 42, 32, 44, 51, 60,
#        35, 50, 38, 38, 38, 63, 24, 49, 25, 47, 33, 28, 54, 20, 57, 64, 44,
#        62, 44, 44, 47, 40, 28, 41, 20, 40, 41, 64, 44, 26, 22, 56, 32, 52,
#        45, 37, 28, 21, 46, 44, 68, 34, 45, 56, 26, 23, 62, 60, 33, 33, 33,
#        20, 66, 20, 61, 54, 28, 27, 36, 37, 52, 30, 52, 40, 53, 60, 36, 59,
#        35, 24, 39, 29, 23, 62, 31, 41, 31, 22, 36, 59, 38, 60, 62, 20, 42,
#        32, 42, 38, 61, 67, 64, 27, 26, 34, 37, 23, 64, 47, 63, 51, 38, 37,
#        64, 39, 34, 53, 24, 53, 44, 66, 54, 22, 43, 52, 65, 59, 63, 40, 65,
#        51, 20, 56, 38, 26, 29, 40, 61, 56, 25, 42, 66, 47, 26, 20, 34, 26,
#        54, 56, 63, 23, 46, 65, 67, 66, 47, 37, 50, 50, 49, 30, 31, 63, 24,
#        48, 21, 26, 66, 31, 43, 20, 44, 36, 56, 20, 49, 42, 29, 54, 64, 63,
#        45, 59, 49, 60, 39, 33, 46, 38, 49, 45, 45, 37, 22, 56, 66, 46, 31,
#        59, 20, 32, 22, 23, 22, 47, 62, 57, 65, 57, 39, 51, 47, 53, 41, 29,
#        30, 44, 29, 24, 24, 31, 33, 67, 32, 57, 57, 52, 49, 36, 54, 68, 64,
#        48, 40, 44, 43, 34, 59, 64, 31, 34, 39, 50, 58, 37, 58, 66, 64, 53,
#        56, 49, 31, 39, 51, 35, 65, 50, 36, 33, 66, 50, 20, 30, 38, 57, 32,
#        20, 37, 39, 42, 35, 64, 34, 20, 38, 68, 42, 61, 67, 50, 40, 25, 47,
#        23, 32, 64, 51, 66, 28, 50, 58, 37, 59, 56, 33, 31, 24, 53, 60, 68,
#        33, 34, 23, 62, 69, 28, 31, 28, 53])

# %%
plt.hist(age)
plt.show()

# %% [markdown]
# ## 2) Gender
# Men face a greater risk of heart disease than women. On average, a first heart attack strikes men at age 65. For women, the average age of a first heart attack is 72 [[2]](https://www.health.harvard.edu/heart-health/the-heart-attack-gender-gap). This is a non-numerical parameter -a string- which follows a Bernoulli distribution since there are just 2 possible outcomes (man and woman) being one of them more likely to occur (men).

# %%
# First declare the two genders
possible_genders = ['male','female']
# and then the corresponding array
gender =  [np.random.choice(possible_genders) for i in range(400)]
gender
# Out:
# ['female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female']

# %%
# Generation of a pandas data frame
df = pd.DataFrame({"gender": gender})

# The creation of the plot takes just two lines
sns.set_style("whitegrid")
sns.countplot(x="gender", data=df)
plt.show()

# %% [markdown]
# ## 3) Family history
# Having a family history of cardiovascular disease increases the risk of developing cardiovascular diseases such as heart attacks. Genes can pass on the risk of cardiovascular disease, and they can also be responsible for passing on other conditions such as high blood pressure or high cholesterol levels [[3]](https://www.bhf.org.uk/informationsupport/risk-factors/family-history).
#
# For this excercise I will consider just 2 possible outcomes, the existance of a family history as 'Yes' or its absence as 'No'. This means that this variable holds strings however the likelyhood of both outcomes are not balanced. I could try to roughly estimate this by considering some facts from the Irish population like:
#
# - Around 10.000 people die every year for cardiovascular disorders [[4]](https://www.hse.ie/eng/health/az/c/coronary-heart-disease/)
# - The population in 2016 was nearly 4.800.000 according to CSO [[5]](https://www.cso.ie/en/releasesandpublications/ep/p-cpr/censusofpopulation2016-preliminaryresults/)
#
# But that would lead to a different project so for the puropose of this test the following figure doesn't need to be representative, it just means the difference in probability of every ocurrence. Then let's just say that a 30% of the people in Ireland has relatives who have had cardiovascular issues including all ranges of severity. Then the likelyhood of having a family history is 30%, and therefore the probability of not having a family history is 70%

# %%
# array generation
possible_fHist = ['Yes','No']
fHist = np.random.choice(possible_fHist, 400, p=[0.3, 0.7])
# plot
df = pd.DataFrame({"Family history": fHist})
sns.countplot(x="Family history", data=df)
plt.show()

# %% [markdown]
# <img style="float: right;" src="https://www.sec.gov/Archives/edgar/data/12239/000110465912018448/g72481mmi005.jpg" alt="LDL cholesterol level" width="450" />
#
# ## 4) Blood Cholesterol
#
# LDL cholesterol travels from the liver through the arteries to other parts of our body. LDL is called bad cholesterol because it sticks to the walls in our arteries making them narrow. The image on the right shows the ranges of blood LDL cholesterol:
#
# In order to force the data set to be more representative of reality I am going to align this variable with the other two variables *age* and *gender* according to the statement given at the top of this document in the "Age" section: *Men age 45 or older and women age 55 or older are more likely to have a heart attack than are younger men and women* [[1]](https://www.mayoclinic.org/diseases-conditions/heart-attack/symptoms-causes/syc-20373106). This way I will assign higher  levels of this bad cholesterol to men older than 44 and women older than 54 because they are more likely to have a heart attack.
#
# When it comes to this variable itself, it is numerical and depending on how specific the machine that processes the blood sample is, we could label it as discrete or continuous. This is, if it returns an integer, then it would be discrete but if the figure has several decimals, then we can take it as continuous.
#
# Then, before anything else I will create the data set table I have so far because only after this, I will be able to iterate row by row and create a new array depending on the values of the cells, and which will turn into the following column of the data.

# %%
# Create a table with the synthetised data set
df = pd.DataFrame({'age': age, 'gender': gender, 'Family history': fHist})
# to start the index from 1 rather than 0
df.index = np.arange(1, len(df) + 1)
# Align the columns at the center with the style feature
df.style.set_properties(**{'text-align': 'center'})
# Out:
# <style  type="text/css" >
#     #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row0_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row0_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row0_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row1_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row1_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row1_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row2_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row2_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row2_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row3_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row3_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row3_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row4_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row4_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row4_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row5_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row5_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row5_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row6_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row6_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row6_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row7_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row7_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row7_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row8_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row8_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row8_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row9_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row9_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row9_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row10_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row10_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row10_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row11_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row11_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row11_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row12_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row12_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row12_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row13_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row13_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row13_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row14_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row14_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row14_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row15_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row15_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row15_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row16_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row16_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row16_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row17_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row17_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row17_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row18_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row18_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row18_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row19_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row19_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row19_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row20_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row20_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row20_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row21_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row21_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row21_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row22_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row22_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row22_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row23_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row23_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row23_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row24_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row24_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row24_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row25_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row25_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row25_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row26_col0 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row26_col1 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row26_col2 {
#             text-align:  center;
#         }    #T_83dc153a_ff2a_11e8_8e1b_e4b97a164a74row27_col0 {

# %% [markdown]
# Now I can proceed with the new array creation:

# %%
# Synthesis of an empty array which will be populated by iterating the rows of the table above. 
bloodChol = []

# this function will generate the values and will be called every row with different arguments 
# depending on the gender and age
def choiceChol(a, b):
    x = np.random.randint(a,b) + np.random.rand()
    bloodChol.append(x)

for index, row in df.iterrows():
    if row.gender == 'male' and row.age > 45:
        choiceChol(159, 200)  
    elif row.gender == 'male' and row.age < 45:
        choiceChol(75, 150)
    elif row.gender == 'female' and row.age > 55:
        choiceChol(159, 200)
    else:
        choiceChol(75, 150)
        
bloodChol
# Out:
# [193.9302979276215,
#  113.50377299416039,
#  78.21512460810087,
#  192.7081010577206,
#  161.272449402406,
#  177.1760848893926,
#  196.0895841864717,
#  107.24602532232605,
#  121.79231172098272,
#  106.32105047383732,
#  88.81395375983773,
#  92.18745086109247,
#  148.0782304026914,
#  89.08979502490303,
#  130.91135078683766,
#  107.74408307193336,
#  82.54948302179537,
#  159.62584618172076,
#  95.09414261853857,
#  187.82994205535277,
#  113.07789687206949,
#  97.07154796480874,
#  178.076376482724,
#  80.22289526955045,
#  116.15069381750094,
#  169.364632674929,
#  161.19651177969467,
#  135.2961080541171,
#  183.81090367293183,
#  193.94506693750083,
#  105.99878284424642,
#  162.35596898280698,
#  76.01702619889512,
#  192.7413906005956,
#  86.77504174784683,
#  128.0951998164807,
#  171.6775891747515,
#  100.43675355187787,
#  90.3224606281009,
#  171.74777811770824,
#  130.43364645644675,
#  186.13228102084705,
#  180.68251386830102,
#  91.19264429732823,
#  93.90521728466551,
#  198.35499540453682,
#  168.31453962690642,
#  130.4010433053585,
#  124.76993300678528,
#  199.52210798748712,
#  107.51382807551278,
#  144.9705356177177,
#  186.46073715614003,
#  128.6142812847268,
#  161.95404519884852,
#  175.79793444353402,
#  84.30303135335659,
#  131.65851157896805,
#  120.84741024600628,
#  111.21393441343135,
#  166.0089136646313,
#  148.13036098134614,
#  188.40772386584408,
#  80.69044203718924,
#  79.22430515499242,
#  111.72792548107232,
#  143.1628165465701,
#  97.47261317289438,
#  116.02148763326504,
#  94.78749858100451,
#  92.95457248414029,
#  117.82450254753122,
#  99.06969558019394,
#  197.91171775019544,
#  136.63248625720874,
#  94.2729058144169,
#  160.23872222325662,
#  165.43468783632983,
#  192.09919407030205,
#  159.42308458668793,
#  161.15000873320963,
#  166.70610448343712,
#  99.86995710313832,
#  196.05005193034683,
#  144.47834269939165,
#  81.2157469767555,
#  114.1583182380845,
#  117.05560348387412,
#  171.76194251878945,
#  95.84431691406769,
#  186.53886382486183,
#  149.15565288897955,
#  167.88003413063143,
#  84.02744842462455,
#  101.77971685317331,
#  189.0262759314956,
#  142.25184268674641,
#  94.17835298861615,
#  129.14195194388085,
#  138.08382512891512,
#  131.26128095965188,
#  169.10240963530734,
#  93.20715052985902,
#  164.9140931843659,
#  145.69377120298597,
#  144.0902020652137,
#  142.66953458753372,
#  197.31716348976175,
#  128.67441119637405,
#  94.48048786421164,
#  84.32759217443389,
#  139.41070841303747,
#  75.34018160219142,
#  133.66083089703372,
#  187.7056839241182,
#  118.41389145747101,
#  176.11943230847436,
#  195.2566788844571,
#  103.27733338523281,
#  176.59718202802014,
#  103.82276964855285,
#  116.2663832939812,
#  137.85974315516063,
#  125.78344656558043,
#  144.3599882799058,
#  98.99468197535873,
#  77.66906250751788,
#  87.45133465029542,
#  122.44926437812596,
#  163.92403760438194,
#  122.23235537805745,
#  90.0794362670914,
#  89.28044602297791,
#  199.3345977618128,
#  144.2574624672808,
#  182.43063325474412,
#  149.38663012607427,
#  92.42073363398855,
#  129.68808306852233,
#  121.31419422367395,
#  120.5002541290362,
#  133.06244171216315,
#  163.27427433961316,
#  128.7560498772349,
#  84.67093411621991,
#  180.22827962101357,
#  143.1196292359602,
#  107.2883468568488,
#  170.41650064695102,
#  179.0940275773853,
#  145.13549856151255,
#  102.4684656778777,
#  124.09269906425304,
#  139.93813914587122,
#  173.0343386114115,
#  109.48702175951748,
#  161.11978831958703,
#  197.40202926766415,
#  98.30343963981548,
#  140.67948440097294,
#  135.98564557658977,
#  82.33631715813922,
#  175.91410615797116,
#  127.78847006194587,
#  172.6344733914553,
#  143.57774247338932,
#  176.89735701842721,
#  180.7435307362503,
#  133.12201114669276,
#  182.8704818911427,
#  145.63848698766193,
#  141.32785121923212,
#  129.77890019272039,
#  133.26672607709108,
#  97.07290876728344,
#  175.4445193441109,
#  138.3345354092651,
#  128.8612435580103,
#  87.63079817560556,
#  122.63397955159242,
#  135.24719517668555,
#  174.80725699551263,
#  132.08907890337574,
#  161.39445160808066,
#  162.252234458581,
#  83.71710949535061,
#  146.47025893440946,
#  144.5489002179594,
#  149.85136992690258,
#  131.84991810747772,
#  187.55952688102835,
#  194.33863081198277,
#  188.38472274584763,
#  79.48805634072082,
#  86.43335719171534,
#  127.36562002956727,
#  113.50136136090258,
#  141.97457376453707,
#  178.42672738091395,
#  182.4702658457092,
#  193.02704605667893,
#  171.6187716929902,
#  103.44856801161072,
#  138.4990813818717,
#  171.86657023130107,
#  134.64768179696716,
#  90.92600751977503,
#  170.0921851219689,
#  114.46036868897541,
#  161.89879105707982,
#  140.4336200405551,
#  190.71897632876914,
#  145.81170652799926,
#  80.69460203579013,
#  149.25646102231747,
#  184.0315435091638,
#  163.94233403077928,
#  160.18883516143657,
#  195.9344844153838,
#  78.97260310336671,
#  179.73691150160437,
#  199.80027699060605,
#  132.37277701071102,
#  162.75130183390925,
#  132.91912136021236,
#  77.12984268976591,
#  76.15569408897944,
#  143.46184818045154,
#  170.70050943063427,
#  173.02814835184915,
#  77.58198335199724,
#  111.24687798021311,
#  195.46823894609787,
#  181.66721356119768,
#  80.3965223769643,
#  144.95015718830766,
#  109.517906548415,
#  131.41147712618863,
#  165.0306807453066,
#  197.56866085910076,
#  189.89729328128004,
#  144.93735709664804,
#  147.89862351129366,
#  169.15583412772673,
#  170.7850591326572,
#  181.93659276842226,
#  99.50740930971529,
#  103.8749939867465,
#  166.82608935329654,
#  159.08035229003235,
#  175.0550232577108,
#  104.10259020778368,
#  94.06510872055065,
#  190.3994065510781,
#  91.86388276281376,
#  162.87331358019802,
#  111.94701886829552,
#  106.67897552585818,
#  160.68154308516418,
#  135.06754383091175,
#  132.8599058345064,
#  84.14720027960288,
#  100.1795698253621,
#  119.55363429177369,
#  183.48956873794262,
#  131.25565735275273,
#  114.18463758376146,
#  77.14314194613492,
#  75.59564317607337,
#  163.4604377282068,
#  193.06617828012114,
#  181.71917994380334,
#  94.10004633502379,
#  181.8434577367778,
#  159.39507257979278,
#  175.45055638343754,
#  114.01696640538574,
#  106.3832569112927,
#  80.2341354231214,
#  109.04601241739667,
#  76.73518186242414,
#  125.08534933551677,
#  106.32472040216135,
#  136.79199181348295,
#  149.15249195800783,
#  162.72080643019814,
#  194.37276979518307,
#  127.07029980494544,
#  80.27305752095774,
#  171.67391713749996,
#  95.15236267705835,
#  105.70538502707906,
#  121.37569318768792,
#  116.19947119544936,
#  100.94396042629738,
#  168.29890994692445,
#  165.77483264009297,
#  163.38628786723328,
#  159.08513290821705,
#  168.7416188199831,
#  129.37781721080972,
#  184.200806380241,
#  88.07677071015746,
#  186.7441506044275,
#  97.35640297962003,
#  120.61396127382746,
#  131.76069501705246,
#  82.83702823234981,
#  115.77133122022502,
#  112.23783086716826,
#  99.47898464070286,
#  100.094847214572,
#  114.28912162622053,
#  175.31062127056705,
#  126.57393309512238,
#  187.6769801222408,
#  167.2241620456677,
#  159.83431844744115,
#  166.95881353265256,
#  106.27246026610366,
#  166.52928678416546,
#  159.61522636707835,
#  165.8165737882074,
#  118.69729918004317,
#  135.00259763086072,
#  104.1025833738953,
#  137.7448581004619,
#  104.13719570961693,
#  172.52347095809048,
#  181.94517142857597,
#  129.41859317668457,
#  99.3717508114892,
#  90.44833519382308,
#  197.31460848520578,
#  174.1219456407451,
#  89.72728826479339,
#  191.6915211977575,
#  198.769880205855,
#  164.07170518964057,
#  111.28547485015422,
#  179.82683763382903,
#  160.38591322175645,
#  101.15225569052399,
#  131.7873654179693,
#  99.09379820190792,
#  118.09075223396654,
#  165.1654298194777,
#  145.40634939779812,
#  96.57097765513306,
#  114.28581566543517,
#  171.5036446636681,
#  183.12669627494947,
#  82.61458629847763,
#  138.22966653454785,
#  93.01000781862662,
#  182.4434647849595,
#  136.3659750015806,
#  84.11881379133297,
#  109.86983802992778,
#  80.20934133955217,
#  130.1874873929656,
#  121.87369865029308,
#  185.66579744651057,
#  149.36272952710357,
#  122.7717823479869,
#  132.08160078225674,
#  172.38306024486417,
#  120.64265656704498,
#  181.12383094667263,
#  176.14025062125424,
#  139.28798359383123,
#  87.74982737307464,
#  134.76667080348278,
#  159.38366717343243,
#  105.43177543666577,
#  78.3994898062057,
#  176.8764257356365,
#  123.64102183968983,
#  176.66649442029873,
#  106.95096052482567,
#  199.54239284195933,
#  183.80856343352266,
#  131.68061300589505,
#  159.49562068002345,
#  170.8579329144706,
#  146.00284153196347,
#  99.42320090339689,
#  117.2450305663685,
#  106.85852990158915,
#  170.43898937146264,
#  196.2861751861028,
#  127.74863869479157,
#  111.47046440746995,
#  108.21020986525338,
#  185.74084943781946,
#  194.42563855115156,
#  135.7067730852943,
#  82.71075845606865,
#  91.31376507016256,
#  112.82092938412819]

# %%
plt.hist(bloodChol, bins = 100)
df = pd.DataFrame({"Blood cholesterol": bloodChol})
plt.show()

# %% [markdown]
# There is a gap visible, I didn't assign any values between 149 and 158 for being the top of the bordeline high level

# %% [markdown]
# ## 5) Smoking
#
# The results of Healthy Ireland survey published in 2015 found that 19% of the Irish population (aged 15 and over) smoke on a daily basis. A further 4% identify themselves as occasional smokers [[6]](https://health.gov.ie/healthy-ireland/tobacco/smoking-prevalence-rates/). Then, regardless of the number of cigarettes they consum I will consider the consumption frequency only, being therefore a variable that holds strings instead of numerical values.
#
# For this I'll assign each of the three possible outcomes a different probability according to the result of the Healthy Ireland survey quoted above:

# %%
# First I declare three variables that represent each consumption frequency
consumption_type = ['Regular','Occasional','Non-smoker']

# Generation of the array that contains the 400 samples with their corresponding probability
smokers = np.random.choice(consumption_type, 400, p=[0.19, 0.04, 0.77])
df = pd.DataFrame({"Tobacco consumption": smokers})
sns.countplot(x="Tobacco consumption", data=df)
plt.show()

# %% [markdown]
# And the updated table with the last variable included is:

# %%
df = pd.DataFrame({'age': age, 'gender': gender, 'Family history': fHist, 'Blood cholesterol': bloodChol, 'Tobacco consumption': smokers})
# to start the index from 1 rather than 0
df.index = np.arange(1, len(df) + 1)
# Align the columns at the center with the style feature
df.style.set_properties(**{'text-align': 'center'})
# Out:
# <style  type="text/css" >
#     #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row0_col0 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row0_col1 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row0_col2 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row0_col3 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row0_col4 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row1_col0 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row1_col1 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row1_col2 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row1_col3 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row1_col4 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row2_col0 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row2_col1 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row2_col2 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row2_col3 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row2_col4 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row3_col0 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row3_col1 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row3_col2 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row3_col3 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row3_col4 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row4_col0 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row4_col1 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row4_col2 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row4_col3 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row4_col4 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row5_col0 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row5_col1 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row5_col2 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row5_col3 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row5_col4 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row6_col0 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row6_col1 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row6_col2 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row6_col3 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row6_col4 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row7_col0 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row7_col1 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row7_col2 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row7_col3 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row7_col4 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row8_col0 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row8_col1 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row8_col2 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row8_col3 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row8_col4 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row9_col0 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row9_col1 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row9_col2 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row9_col3 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row9_col4 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row10_col0 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row10_col1 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row10_col2 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row10_col3 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row10_col4 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row11_col0 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row11_col1 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row11_col2 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row11_col3 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row11_col4 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row12_col0 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row12_col1 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row12_col2 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row12_col3 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row12_col4 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row13_col0 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row13_col1 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row13_col2 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row13_col3 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row13_col4 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row14_col0 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row14_col1 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row14_col2 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row14_col3 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row14_col4 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row15_col0 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row15_col1 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row15_col2 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row15_col3 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row15_col4 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row16_col0 {
#             text-align:  center;
#         }    #T_85a111f4_ff2a_11e8_809a_e4b97a164a74row16_col1 {
#             text-align:  cente

# %% [markdown]
# ## 6) Obesity
# Obesity is a risk factor for fatal heart attacks even for people who do not have the conditions normally associated with cardiovascular disease. A recent study published in April 2018 in the journal JAMA Cardiology [[7]](https://www.ncbi.nlm.nih.gov/pubmed/29490333) concluded that adults between ages 40 and 59 who are overweight or obese have a significantly increased risk (ranging from 21 to 85 percent higher) of developing cardiovascular disease as compared with their normal weight peers. Individuals who are overweight, defined as having a body mass index (BMI) between 25 and 29.9, or are obese (a BMI of 30 or higher), also have a much greater risk of developing cardiovascular disease at a younger age.
#
# Then I will generate the BMI for the sample of population considering the obesity prevalence of the Irish population according to this study [[8]](https://www.safefood.eu/SafeFood/media/SafeFoodLibrary/Documents/Professional/Nutrition/Adult-and-children-obesity-trends-ROI.pdf)

# %% [markdown]
# ![Obesity prevalence by age](attachment:image.png)

# %% [markdown]
# We see that the men data follows a triangular distribution with its peak on the right where the age range 50 - 59. However women's distribution tends to be more linear despite the age range 30 - 39 is slighty lower.
#
# Then I'll apply the results of this study to give person by person a BMI depending on their age:

# %%
'''Create an empty array whose values will be added by iteration with the help of a function. Note that
this variable has to be created out of the below function because it has to be visible for the rest of 
the code (global scope)'''
BMI = []

'''This function will be called one table row at a time to:
1) Decide whether that person will have a 'normal' BMI or an 'obese' one, given the probability of suffering
obesity considering gender and age
2) Generate a random number from the chosen BMI range'''

def choiceBMI(a, b):
    
    # Creation of labels for both BMI options
    altBMI = ['normal', 'obese']
    
    # Election itself (coin toss with a probability which will be assigned when calling this function)
    z = np.random.choice(altBMI, 1, p=[a, b])
    
    if z == 'normal':
        # The BMI is generated as the addition of an integer and a one-decimal float
        z2 = np.random.randint(20,30) + np.random.randint(10)/10
        BMI.append(z2)
        
    else:
        z2 = np.random.randint(30,36) + np.random.randint(10)/10
        BMI.append(z2)
    return z2;

# Iteration through the table row by row
for index, row in df.iterrows():
    
    if row.gender == 'male':
        if 20 < row.age < 29:
            # we call the above function considering the corresponding probabilities for gender and age
            choiceBMI(0.88,0.12)
        elif 30 < row.age < 39:
            choiceBMI(0.72,0.28)
        elif 40 < row.age < 49:
            choiceBMI(0.70,0.30)
        elif 50 < row.age < 59:
            choiceBMI(0.59,0.41)
        else:
            choiceBMI(0.69,0.31)
        
        
    else:
        if 20 < row.age < 29:
            choiceBMI(0.86,0.14)
        elif 30 < row.age < 39:
            choiceBMI(0.87,0.13)
        elif 40 < row.age < 49:
            choiceBMI(0.75,0.25)
        elif 50 < row.age < 59:
            choiceBMI(0.72,0.28)
        else:
            choiceBMI(0.77,0.23)
BMI
# Out:
# [23.3,
#  29.3,
#  27.7,
#  34.7,
#  31.6,
#  28.2,
#  24.3,
#  23.4,
#  23.7,
#  28.3,
#  31.4,
#  20.8,
#  26.3,
#  34.7,
#  29.0,
#  20.5,
#  20.9,
#  21.2,
#  25.5,
#  22.5,
#  21.4,
#  21.0,
#  23.7,
#  30.1,
#  28.5,
#  25.5,
#  29.8,
#  21.1,
#  24.2,
#  35.3,
#  26.2,
#  30.7,
#  20.6,
#  22.3,
#  28.6,
#  28.5,
#  26.1,
#  30.8,
#  20.9,
#  25.5,
#  22.6,
#  30.0,
#  31.6,
#  26.1,
#  25.7,
#  31.3,
#  22.3,
#  25.4,
#  20.4,
#  29.0,
#  22.9,
#  21.9,
#  25.4,
#  26.4,
#  31.4,
#  31.4,
#  22.8,
#  29.0,
#  29.3,
#  27.1,
#  22.5,
#  28.9,
#  21.7,
#  29.9,
#  25.5,
#  20.4,
#  25.5,
#  34.9,
#  22.1,
#  31.6,
#  22.6,
#  32.3,
#  24.4,
#  20.3,
#  35.0,
#  27.3,
#  25.7,
#  22.3,
#  35.8,
#  30.2,
#  25.9,
#  23.1,
#  25.5,
#  21.6,
#  25.2,
#  23.7,
#  28.2,
#  35.0,
#  28.1,
#  25.0,
#  35.6,
#  23.2,
#  25.5,
#  25.2,
#  28.2,
#  22.2,
#  28.9,
#  23.7,
#  32.1,
#  33.5,
#  25.6,
#  21.1,
#  21.1,
#  27.9,
#  28.1,
#  23.4,
#  21.7,
#  28.9,
#  29.1,
#  26.0,
#  27.5,
#  32.7,
#  27.0,
#  21.0,
#  31.0,
#  31.0,
#  31.2,
#  20.3,
#  31.4,
#  20.6,
#  34.9,
#  34.0,
#  31.7,
#  25.3,
#  27.5,
#  24.9,
#  20.2,
#  28.5,
#  24.5,
#  26.3,
#  28.9,
#  22.8,
#  35.8,
#  31.4,
#  24.2,
#  29.4,
#  21.3,
#  33.1,
#  24.4,
#  25.9,
#  26.4,
#  27.8,
#  31.3,
#  22.5,
#  30.7,
#  32.0,
#  23.2,
#  28.9,
#  24.9,
#  35.9,
#  21.2,
#  35.6,
#  23.8,
#  26.5,
#  28.4,
#  28.3,
#  25.0,
#  35.8,
#  35.9,
#  29.2,
#  31.0,
#  25.6,
#  30.8,
#  22.4,
#  30.4,
#  32.2,
#  29.1,
#  29.7,
#  23.1,
#  20.8,
#  25.1,
#  24.0,
#  28.7,
#  20.5,
#  28.1,
#  32.1,
#  32.9,
#  30.0,
#  24.1,
#  26.8,
#  23.6,
#  23.6,
#  22.3,
#  28.1,
#  23.8,
#  35.1,
#  32.2,
#  34.8,
#  21.6,
#  35.0,
#  33.5,
#  28.3,
#  27.9,
#  20.9,
#  30.2,
#  27.2,
#  23.2,
#  22.6,
#  26.1,
#  21.7,
#  24.5,
#  22.0,
#  26.6,
#  32.6,
#  24.1,
#  20.4,
#  23.7,
#  32.7,
#  24.0,
#  31.5,
#  27.7,
#  32.1,
#  26.8,
#  31.4,
#  26.7,
#  21.5,
#  29.1,
#  24.7,
#  29.8,
#  29.1,
#  29.5,
#  27.1,
#  29.3,
#  31.5,
#  34.6,
#  22.5,
#  35.1,
#  24.5,
#  35.1,
#  35.9,
#  27.6,
#  24.4,
#  24.8,
#  25.7,
#  28.1,
#  22.2,
#  25.1,
#  26.4,
#  35.0,
#  31.8,
#  25.5,
#  25.8,
#  33.4,
#  31.7,
#  24.4,
#  29.4,
#  23.4,
#  22.2,
#  33.3,
#  22.8,
#  21.4,
#  20.4,
#  28.3,
#  21.5,
#  23.1,
#  27.3,
#  24.3,
#  21.3,
#  20.5,
#  25.6,
#  25.0,
#  24.2,
#  23.8,
#  21.8,
#  31.1,
#  25.3,
#  25.3,
#  29.6,
#  21.1,
#  33.2,
#  26.3,
#  35.3,
#  20.1,
#  20.3,
#  32.8,
#  22.3,
#  29.8,
#  24.9,
#  22.7,
#  35.4,
#  34.6,
#  20.9,
#  20.7,
#  35.3,
#  30.5,
#  33.4,
#  24.4,
#  22.2,
#  20.2,
#  28.0,
#  21.9,
#  28.3,
#  33.0,
#  29.8,
#  28.0,
#  22.5,
#  21.6,
#  22.9,
#  31.9,
#  30.1,
#  27.3,
#  22.2,
#  29.4,
#  27.3,
#  33.7,
#  24.8,
#  27.7,
#  30.1,
#  31.7,
#  20.2,
#  23.2,
#  29.1,
#  27.5,
#  32.4,
#  28.9,
#  25.6,
#  27.0,
#  24.9,
#  35.6,
#  27.1,
#  20.9,
#  25.7,
#  21.8,
#  34.7,
#  25.5,
#  34.4,
#  29.9,
#  29.7,
#  22.6,
#  23.2,
#  21.3,
#  26.1,
#  32.9,
#  25.1,
#  34.1,
#  24.1,
#  35.6,
#  23.1,
#  35.6,
#  28.1,
#  25.1,
#  23.6,
#  26.1,
#  20.2,
#  23.7,
#  22.7,
#  27.7,
#  21.0,
#  34.5,
#  21.7,
#  27.4,
#  28.8,
#  25.6,
#  26.9,
#  21.4,
#  20.2,
#  28.6,
#  31.0,
#  23.9,
#  20.2,
#  34.1,
#  29.0,
#  35.5,
#  21.7,
#  23.8,
#  21.3,
#  27.5,
#  27.9,
#  35.6,
#  32.9,
#  22.3,
#  22.6,
#  26.9,
#  35.4,
#  27.9,
#  22.1,
#  20.6,
#  35.2,
#  22.5,
#  20.6,
#  32.7,
#  27.9,
#  30.1,
#  23.1,
#  33.8,
#  28.9,
#  21.5,
#  29.4,
#  21.4,
#  34.3,
#  25.7,
#  25.3,
#  35.1,
#  32.8,
#  20.4,
#  31.0,
#  29.5,
#  23.7,
#  25.5,
#  21.6]

# %%
df = pd.DataFrame({'age': age, 'gender': gender, 'Family history': fHist, 'Blood_cholesterol': bloodChol, 'Tobacco consumption': smokers, 'BMI': BMI})
# to start the index from 1 rather than 0
df.index = np.arange(1, len(df) + 1)
# Align the columns at the center with the style feature
df.style.set_properties(**{'text-align': 'center'})
# Out:
# <style  type="text/css" >
#     #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row0_col0 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row0_col1 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row0_col2 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row0_col3 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row0_col4 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row0_col5 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row1_col0 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row1_col1 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row1_col2 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row1_col3 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row1_col4 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row1_col5 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row2_col0 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row2_col1 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row2_col2 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row2_col3 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row2_col4 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row2_col5 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row3_col0 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row3_col1 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row3_col2 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row3_col3 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row3_col4 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row3_col5 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row4_col0 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row4_col1 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row4_col2 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row4_col3 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row4_col4 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row4_col5 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row5_col0 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row5_col1 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row5_col2 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row5_col3 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row5_col4 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row5_col5 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row6_col0 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row6_col1 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row6_col2 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row6_col3 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row6_col4 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row6_col5 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row7_col0 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row7_col1 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row7_col2 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row7_col3 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row7_col4 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row7_col5 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row8_col0 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row8_col1 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row8_col2 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row8_col3 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row8_col4 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row8_col5 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row9_col0 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row9_col1 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row9_col2 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row9_col3 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row9_col4 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row9_col5 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row10_col0 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row10_col1 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row10_col2 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row10_col3 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row10_col4 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row10_col5 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row11_col0 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row11_col1 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row11_col2 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row11_col3 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row11_col4 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row11_col5 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row12_col0 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row12_col1 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row12_col2 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row12_col3 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row12_col4 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row12_col5 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row13_col0 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row13_col1 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row13_col2 {
#             text-align:  center;
#         }    #T_873a5f4c_ff2a_11e8_9c02_e4b97a164a74row13_col3 {
#             text-align:  center;

# %% [markdown]
# And finally, while having a look at the table I spot some row values that could clash at first. For the purpose of this test I will reset the values of the blood cholesterol from the people who have a high BMI but a low blood cholesterol (the expected thing is that the more overweighted the higher the cholesterol rate).

# %%
newBloodChol = []
for index, row in df.iterrows():
    if row.BMI > 31.5 and row.Blood_cholesterol < 159:
        z3 = np.random.randint(159,200) + np.random.rand()
        df.at[index, 'Blood_cholesterol'] = z3
        newBloodChol.append(z3)
    else:
        z3 = df.at[index, 'Blood_cholesterol']
        newBloodChol.append(z3) 
        
# Just checking the lenght of the array
len(newBloodChol)
# Out:
# 400

# %% [markdown]
# And the final table would be:

# %%
df = pd.DataFrame({'age': age, 'gender': gender, 'Family history': fHist, 'Blood_cholesterol': newBloodChol, 'Tobacco consumption': smokers, 'BMI': BMI})
# to start the index from 1 rather than 0
df.index = np.arange(1, len(df) + 1)
# Align the columns at the center with the style feature
df.style.set_properties(**{'text-align': 'center'})
# Out:
# <style  type="text/css" >
#     #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row0_col0 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row0_col1 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row0_col2 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row0_col3 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row0_col4 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row0_col5 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row1_col0 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row1_col1 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row1_col2 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row1_col3 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row1_col4 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row1_col5 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row2_col0 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row2_col1 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row2_col2 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row2_col3 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row2_col4 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row2_col5 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row3_col0 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row3_col1 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row3_col2 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row3_col3 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row3_col4 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row3_col5 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row4_col0 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row4_col1 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row4_col2 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row4_col3 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row4_col4 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row4_col5 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row5_col0 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row5_col1 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row5_col2 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row5_col3 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row5_col4 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row5_col5 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row6_col0 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row6_col1 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row6_col2 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row6_col3 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row6_col4 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row6_col5 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row7_col0 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row7_col1 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row7_col2 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row7_col3 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row7_col4 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row7_col5 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row8_col0 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row8_col1 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row8_col2 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row8_col3 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row8_col4 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row8_col5 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row9_col0 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row9_col1 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row9_col2 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row9_col3 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row9_col4 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row9_col5 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row10_col0 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row10_col1 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row10_col2 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row10_col3 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row10_col4 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row10_col5 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row11_col0 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row11_col1 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row11_col2 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row11_col3 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row11_col4 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row11_col5 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row12_col0 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row12_col1 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row12_col2 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row12_col3 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row12_col4 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row12_col5 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row13_col0 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row13_col1 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row13_col2 {
#             text-align:  center;
#         }    #T_88c76f5e_ff2a_11e8_b876_e4b97a164a74row13_col3 {
#             text-align:  center;

# %% [markdown]
# Then we can just relate all the variables together to identify relationships between them or spot trends or isolated facts.

# %%
finalDS = pd.DataFrame({'age': age, 'gender': gender, 'Family history': fHist, 'Blood cholesterol': bloodChol, 'Tobacco consumption': smokers})
sns.pairplot(finalDS, hue="Family history", height=4)
plt.show()

# %% [markdown]
# ## References
# - [Numpy official manual](https://docs.scipy.org/doc/numpy/index.html)
# - [Seaborn](https://seaborn.pydata.org/index.html)
# - [1] [Mayo Clinic](https://www.mayoclinic.org/diseases-conditions/heart-attack/symptoms-causes/syc-20373106)
# - [2] [Harvard.edu](https://www.health.harvard.edu/heart-health/the-heart-attack-gender-gap)
# - [3] [British Heart Foundation](https://www.bhf.org.uk/informationsupport/risk-factors/family-history)
# - [4] [HSE](https://www.hse.ie/eng/health/az/c/coronary-heart-disease/)
# - [5] [CSO](https://www.cso.ie/en/releasesandpublications/ep/p-cpr/censusofpopulation2016-preliminaryresults/)
# - [6] [www.health.gov.ie](https://health.gov.ie/healthy-ireland/tobacco/smoking-prevalence-rates/)
# - [7] [www.ncbi.nlm.nih.gov](https://www.ncbi.nlm.nih.gov/pubmed/29490333)
# - [8] [www.safefood.eu](https://www.safefood.eu/SafeFood/media/SafeFoodLibrary/Documents/Professional/Nutrition/Adult-and-children-obesity-trends-ROI.pdf)
# - https://www.health.com/health/gallery/0,,20538581,00.html?slide=121137#121137
