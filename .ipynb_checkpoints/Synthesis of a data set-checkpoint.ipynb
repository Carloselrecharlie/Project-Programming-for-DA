# %% [markdown]
# ### By Carlos Montes
#
# December 2018
#
# In this notebook I am going to look at a real phenomenon of my choice: a health study with a sample of population related to heart disease. A heart attack is usually caused by the buildup of plaque in the coronary arteries. The plaque builds up over time to eventually slow or completely block blood flow to the heart muscle. What matters now is the variables that condition the appearance of this health issue. It's worth mentioning that there may not be a most definitive one by itself, it seems to be just a question of balance between themselves. Anyways they are approximately graded from greater to lesser likelihood of importance.
#
# For the purpose of this exercise I will synthesise a data set with the values of all the risk factor which affect the heart attack. Half of the samples represent males and the other half woman being 400 in total.
#
# ## 1) Age
# As we get older, our risk of a heart attack goes up. Men age 45 or older and women age 55 or older are more likely to have a heart attack than are younger men and women [[1]](https://www.mayoclinic.org/diseases-conditions/heart-attack/symptoms-causes/syc-20373106) This is a discrete numerical variable and for the synthetised data set I am going to generate a sample of 400 people. The age will be presented in years with integer values and following a uniform distribution to garantee that all the age ranges will be equally represented.

# %%
import numpy as np
age = np.random.randint(20,70,size=400)
age
# Out:
# array([55, 43, 53, 58, 68, 20, 41, 46, 24, 56, 33, 29, 61, 32, 30, 29, 22,
#        23, 26, 61, 22, 54, 67, 39, 69, 54, 30, 28, 45, 31, 64, 55, 28, 66,
#        62, 45, 47, 52, 63, 65, 25, 39, 31, 32, 59, 23, 43, 26, 26, 27, 48,
#        42, 32, 29, 48, 37, 37, 25, 42, 44, 68, 39, 69, 60, 38, 22, 31, 46,
#        36, 36, 41, 57, 64, 45, 63, 46, 26, 28, 49, 33, 46, 47, 37, 30, 25,
#        43, 22, 66, 64, 40, 58, 31, 54, 32, 34, 67, 40, 24, 20, 21, 41, 69,
#        65, 69, 48, 66, 22, 43, 41, 26, 51, 48, 38, 67, 36, 51, 44, 29, 48,
#        54, 31, 38, 61, 33, 64, 25, 50, 22, 21, 45, 29, 27, 51, 38, 28, 42,
#        60, 37, 63, 24, 67, 20, 65, 43, 43, 60, 51, 37, 49, 41, 31, 29, 65,
#        28, 37, 39, 49, 35, 58, 39, 53, 46, 32, 54, 65, 28, 64, 33, 69, 66,
#        32, 61, 68, 35, 47, 28, 59, 31, 54, 31, 52, 42, 55, 50, 53, 48, 46,
#        69, 24, 43, 34, 58, 20, 44, 29, 63, 26, 53, 38, 43, 30, 45, 69, 51,
#        57, 32, 48, 29, 37, 42, 61, 21, 21, 46, 51, 36, 61, 26, 20, 25, 20,
#        25, 28, 42, 21, 38, 51, 63, 57, 42, 28, 59, 45, 53, 39, 43, 26, 44,
#        69, 65, 47, 26, 47, 56, 24, 55, 56, 24, 62, 59, 53, 58, 35, 47, 69,
#        40, 56, 68, 53, 62, 67, 25, 54, 48, 61, 48, 42, 63, 24, 29, 46, 38,
#        56, 59, 24, 52, 36, 50, 69, 52, 24, 45, 33, 61, 28, 30, 32, 53, 24,
#        44, 44, 62, 55, 36, 53, 59, 68, 26, 54, 46, 51, 67, 38, 32, 69, 58,
#        31, 65, 57, 61, 34, 57, 25, 59, 31, 64, 65, 38, 25, 62, 53, 39, 54,
#        24, 69, 31, 27, 69, 47, 21, 55, 55, 67, 65, 41, 66, 64, 23, 34, 57,
#        34, 59, 38, 58, 43, 21, 64, 21, 45, 26, 58, 33, 59, 52, 44, 27, 23,
#        22, 59, 52, 52, 51, 34, 55, 57, 22, 42, 32, 51, 32, 40, 39, 33, 63,
#        47, 55, 39, 20, 40, 69, 38, 53, 29, 26, 49, 36, 26, 59, 45, 64, 32,
#        59, 64, 59, 26, 26, 44, 65, 27, 34])

# %%
import matplotlib.pyplot as plt
plt.hist(age)
plt.show()

# %% [markdown]
# ## 2) Gender
# Men face a greater risk of heart disease than women. On average, a first heart attack strikes men at age 65. For women, the average age of a first heart attack is 72 [[2]](https://www.health.harvard.edu/heart-health/the-heart-attack-gender-gap). This is a non-numerical parameter -a string- which follows a Bernoulli distribution since there are just 2 possible outcomes (man and woman) being one of them more likely to occur (men).

# %%
possible_genders = ['male','female']
gender =  [np.random.choice(possible_genders) for i in range(400)]
gender
# Out:
# ['male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male']

# %%
import seaborn as sns
import pandas as pd
df = pd.DataFrame({"gender": gender})

# La creación del plot son dos líneas
sns.set_style("whitegrid")
sns.countplot(x="gender", data=df)
plt.show()

# %% [markdown]
# ## 3) Family history
# Having a family history of cardiovascular disease increases the risk of developing cardiovascular diseases such as heart attacks. Genes can pass on the risk of cardiovascular disease, and they can also be responsible for passing on other conditions such as high blood pressure or high cholesterol levels [[3]](https://www.bhf.org.uk/informationsupport/risk-factors/family-history).
#
# For this excercise I will consider just 2 possible outcomes, the existance of a family history as 'Yes' or its absence as 'No'. This means that this variable holds strings however the likelyhood of both outcomes are not balanced. I could try to roughly estimate this by considering some facts from the Irish population like:
#
# - Around 10.000 people die every year for cardiovascular disorders [[4]](https://www.hse.ie/eng/health/az/c/coronary-heart-disease/)
# - The population in 2016 was nearly 4.800.000 according to CSO [[5]](https://www.cso.ie/en/releasesandpublications/ep/p-cpr/censusofpopulation2016-preliminaryresults/)
#
# But that would lead to a different project so for the puropose of this test the following figure doesn't need to be representative, it just means the difference in probability of every ocurrence. Then let's just say that a 30% of the people in Ireland has relatives who have had cardiovascular issues including all ranges of severity. Then the likelyhood of having a family history is 30%, and therefore the probability of not having a family history is 70%

# %%
possible_fHist = ['Yes','No']
fHist = np.random.choice(possible_fHist, 400, p=[0.3, 0.7])
df = pd.DataFrame({"Family history": fHist})
sns.countplot(x="Family history", data=df)
plt.show()

# %% [markdown]
# <img style="float: right;" src="https://www.sec.gov/Archives/edgar/data/12239/000110465912018448/g72481mmi005.jpg" alt="LDL cholesterol level" width="450" />
#
# ## 4) Blood Cholesterol
#
# LDL cholesterol travels from the liver through the arteries to other parts of our body. LDL is called bad cholesterol because it sticks to the walls in our arteries making them narrow. The image on the right shows the ranges of blood LDL cholesterol:
#
# In order to force the data set to be more representative of reality I am going to align this variable with the other two variables *age* and *gender* according to the statement given at the top of this document in the "Age" section: *Men age 45 or older and women age 55 or older are more likely to have a heart attack than are younger men and women* [[1]](https://www.mayoclinic.org/diseases-conditions/heart-attack/symptoms-causes/syc-20373106). This way I will assign higher  levels of this bad cholesterol to men older than 44 and women older than 54 because they are more likely to have a heart attack.
#
# When it comes to this variable itself, it is numerical and depending on how specific the machine that processes the blood sample is, we could label it as discrete or continuous. This is, if it returns an integer, then it would be discrete but if the figure has several decimals, then we can take it as continuous.

# %%
bloodChol = np.zeros([400])
# Create a table with the synthetised data set
df = pd.DataFrame({'age': age, 'gender': gender, 'Family history': fHist, 'Blood cholesterol': bloodChol})
# Align the columns at the center with the style feature
df.style.set_properties(**{'text-align': 'center'})
# Out:
# <style  type="text/css" >
#     #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row0_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row0_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row0_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row0_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row1_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row1_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row1_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row1_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row2_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row2_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row2_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row2_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row3_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row3_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row3_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row3_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row4_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row4_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row4_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row4_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row5_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row5_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row5_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row5_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row6_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row6_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row6_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row6_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row7_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row7_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row7_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row7_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row8_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row8_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row8_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row8_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row9_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row9_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row9_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row9_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row10_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row10_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row10_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row10_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row11_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row11_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row11_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row11_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row12_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row12_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row12_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row12_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row13_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row13_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row13_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row13_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row14_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row14_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row14_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row14_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row15_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row15_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row15_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row15_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row16_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row16_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row16_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row16_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row17_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row17_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row17_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row17_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row18_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row18_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row18_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row18_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row19_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row19_col1 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row19_col2 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row19_col3 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row20_col0 {
#             text-align:  center;
#         }    #T_7bced86c_fd8f_11e8_a288_e4b97a164a74row20_col1 {
#             text-ali

# %%
for index, row in df.iterrows():
    if row.gender == 'male' and row.age > 45:
        df.at[index, 'Blood cholesterol'] = np.random.randint(159,200) + np.random.rand()
    elif row.gender == 'male' and row.age < 45:
        df.at[index, 'Blood cholesterol'] = np.random.randint(75,130) + np.random.rand()
    elif row.gender == 'female' and row.age > 55:
        df.at[index, 'Blood cholesterol'] = np.random.randint(159,200) + np.random.rand()
    else:
        df.at[index, 'Blood cholesterol'] = np.random.randint(75,130) + np.random.rand()

# %%
bloodCholNew = []
for index, row in df.iterrows():
    if row.gender == 'male' and row.age > 45:
        x = np.random.randint(159,200) + np.random.rand()
        bloodCholNew.append(x)
    elif row.gender == 'male' and row.age < 45:
        x = np.random.randint(75,130) + np.random.rand()
        bloodCholNew.append(x)
    elif row.gender == 'female' and row.age > 55:
        x = np.random.randint(159,200) + np.random.rand()
        bloodCholNew.append(x)
    else:
        x = np.random.randint(75,130) + np.random.rand()
        bloodCholNew.append(x)
        
bloodCholNew
# Out:
# [83.31896130080648,
#  75.05613449813404,
#  78.94708202192982,
#  109.70982642590637,
#  169.5331113711792,
#  127.20193037255137,
#  129.56996194024387,
#  171.51406293697812,
#  129.82722673555702,
#  184.5785723570863,
#  79.93210498835253,
#  86.44271897228995,
#  168.84986592828176,
#  76.96205741141755,
#  189.47090476220544,
#  176.83713420418206,
#  82.93400259145153,
#  160.92902018808104,
#  93.03607580377206,
#  104.92808340986943,
#  196.80176382583625,
#  177.52583607702746,
#  186.74603463026455,
#  177.98888709268064,
#  172.8226782361381,
#  190.53365778833563,
#  196.36740838302205,
#  101.81371055827601,
#  187.1806636283605,
#  110.86382450190064,
#  89.2314188375493,
#  118.42964950009542,
#  97.92009676376577,
#  163.1691910242247,
#  95.04889840521493,
#  173.176710673984,
#  117.02468577473704,
#  196.5053977547843,
#  116.98215074771814,
#  175.36938426122376,
#  96.7098201290038,
#  167.96343497509216,
#  167.51675660513783,
#  119.33107532421506,
#  97.76586679297897,
#  127.82966759478028,
#  111.14765999484591,
#  176.79505246223965,
#  90.68432544894826,
#  197.04654100194062,
#  164.81362862317619,
#  78.03446572611924,
#  180.72824778411373,
#  108.1931253101339,
#  175.69878520079098,
#  184.9125567210969,
#  167.03548347739823,
#  162.38240439490528,
#  164.36408602054414,
#  191.2651212403667,
#  168.5328355917957,
#  178.8560178036367,
#  106.64801063549753,
#  127.30754705415855,
#  161.3800415039723,
#  97.46882361489759,
#  78.33689291849353,
#  176.53245579241653,
#  123.11707624388514,
#  164.70357562175215,
#  103.76079294454406,
#  197.1325017652932,
#  179.0834758978096,
#  180.90153030328025,
#  85.13945675376218,
#  165.39701844623227,
#  165.4812435450981,
#  162.80845081210944,
#  169.8486612827061,
#  178.07616588426313,
#  79.26394155700068,
#  191.41271762959528,
#  105.93511158638466,
#  89.4370074982877,
#  160.41821311886218,
#  106.60213965972152,
#  105.71307301333341,
#  160.32894617638405,
#  196.21379221223287,
#  77.70826317259846,
#  75.4826110806016,
#  159.0052388495437,
#  180.5191719039738,
#  118.01872646158571,
#  80.48454029654258,
#  193.4268554529407,
#  85.24473032422677,
#  187.22017653283353,
#  93.90344428133189,
#  111.39849708309065,
#  121.08589954635497,
#  88.76171774807436,
#  104.64029773292481,
#  193.88532185575207,
#  77.62301064062963,
#  194.72262953426832,
#  82.98622836946232,
#  165.10037976218823,
#  190.1929383922041,
#  105.66446410793253,
#  99.09205397938877,
#  122.15124833700257,
#  95.27648532153222,
#  176.3637813230334,
#  100.80214344047482,
#  125.15741332081183,
#  191.76408051285716,
#  76.68150132347354,
#  75.28708269817292,
#  80.46700432304569,
#  126.30001903536973,
#  172.75919832913655,
#  103.70618753268556]

# %%
#plt.hist(bloodCholNew, bins = 100)
df = pd.DataFrame({"Family history": bloodCholNew})
sns.countplot(x="Family history", data=df)
plt.show()

# %%
df
# Out:
#      age  gender Family history  Blood cholesterol
# 0     36    male             No         121.538920
# 1     30  female             No          93.051468
# 2     20  female             No         119.673260
# 3     37    male            Yes         121.173774
# 4     79  female            Yes         196.721586
# 5     22  female            Yes         127.281587
# 6     83    male            Yes         189.331465
# 7     41    male             No         108.020521
# 8     55    male             No         193.114893
# 9     30    male             No         106.211321
# 10    61    male             No         181.220334
# 11    44    male             No         109.183824
# 12    34    male             No          75.494367
# 13    46    male            Yes         166.709935
# 14    62    male             No         164.314882
# 15    49    male             No         191.460678
# 16    40    male             No          83.579373
# 17    54  female             No          76.395026
# 18    23    male             No          81.882966
# 19    61  female             No         190.129915
# 20    70  female             No         182.830004
# 21    68  female             No         191.626918
# 22    48  female             No         112.274302
# 23    60    male             No         178.112187
# 24    69    male            Yes         186.157380
# 25    82    male            Yes         194.846532
# 26    37  female             No         115.587933
# 27    56    male             No         185.604723
# 28    61    male             No         177.717899
# 29    23    male             No         101.773985
# ..   ...     ...            ...                ...
# 370   25  female             No         102.229585
# 371   54  female             No         112.034061
# 372   68    male             No         193.685007
# 373   29  female             No         104.204252
# 374   58  female            Yes         183.977391
# 375   23  female             No         110.257946
# 376   53  female            Yes          84.662625
# 377   44  female             No         105.594496
# 378   48  female            Yes         129.818870
# 379   36    male             No         104.073744
# 380   80  female             No         188.080832
# 381   28    male            Yes         124.732649
# 382   67    male             No         190.141984
# 383   28    male             No         109.688014
# 384   76  female             No         180.364994
# 385   65    male            Yes         196.968263
# 386   29    male             No         110.118338
# 387   51  female            Yes         111.980285
# 388   51  female             No         119.629679
# 389   39    male            Yes         113.618521
# 390   47    male             No         188.689913
# 391   27    male            Yes          90.363663
# 392   24    male            Yes          84.031104
# 393   66    male             No         185.319905
# 394   38  female             No          99.234920
# 395   44    male             No          79.999722
# 396   25  female             No         125.686692
# 397   45  female             No          83.566450
# 398   63  female             No         197.933982
# 399   40    male             No         125.802115
#
# [400 rows x 4 columns]

# %% [markdown]
# ## 5) Smoking
#
# The results of Healthy Ireland survey published in 2015 found that 19% of the Irish population (aged 15 and over) smoke on a daily basis. A further 4% identify themselves as occasional smokers [[6]](https://health.gov.ie/healthy-ireland/tobacco/smoking-prevalence-rates/). Then, regardless of the number of cigarettes they consum I will consider the consumption frequency only, being therefore a variable that holds strings instead of numerical values.
#
# For this I'll assign each of the three possible outcomes a different probability according to the result of the Healthy Ireland survey quoted above:

# %%
# First I declare three variables that represent each consumption frequency
consumption_type = ['Regular','Occasional','Non-smokers']

# Generation of the array that contains the 400 samples with their corresponding probability
smokers = np.random.choice(consumption_type, 400, p=[0.19, 0.04, 0.77])
df = pd.DataFrame({"Tobacco consumption": smokers})
sns.countplot(x="Tobacco consumption", data=df)
plt.show()

# %% [markdown]
# And the updated table with the last variable included is:

# %%
df = pd.DataFrame({'age': age, 'gender': gender, 'Family history': fHist, 'Blood cholesterol': bloodCholNew, 'Tobacco consumption': smokers})
# Align the columns at the center with the style feature
df.style.set_properties(**{'text-align': 'center'})
# Out:
# <style  type="text/css" >
#     #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row0_col0 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row0_col1 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row0_col2 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row0_col3 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row0_col4 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row1_col0 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row1_col1 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row1_col2 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row1_col3 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row1_col4 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row2_col0 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row2_col1 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row2_col2 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row2_col3 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row2_col4 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row3_col0 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row3_col1 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row3_col2 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row3_col3 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row3_col4 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row4_col0 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row4_col1 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row4_col2 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row4_col3 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row4_col4 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row5_col0 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row5_col1 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row5_col2 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row5_col3 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row5_col4 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row6_col0 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row6_col1 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row6_col2 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row6_col3 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row6_col4 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row7_col0 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row7_col1 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row7_col2 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row7_col3 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row7_col4 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row8_col0 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row8_col1 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row8_col2 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row8_col3 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row8_col4 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row9_col0 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row9_col1 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row9_col2 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row9_col3 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row9_col4 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row10_col0 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row10_col1 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row10_col2 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row10_col3 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row10_col4 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row11_col0 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row11_col1 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row11_col2 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row11_col3 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row11_col4 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row12_col0 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row12_col1 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row12_col2 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row12_col3 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row12_col4 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row13_col0 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row13_col1 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row13_col2 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row13_col3 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row13_col4 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row14_col0 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row14_col1 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row14_col2 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row14_col3 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row14_col4 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row15_col0 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row15_col1 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row15_col2 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row15_col3 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row15_col4 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row16_col0 {
#             text-align:  center;
#         }    #T_7d97fa36_fd8f_11e8_954f_e4b97a164a74row16_col1 {
#             text-align:  cente

# %% [markdown]
# ## 6) Obesity
# Obesity is a risk factor for fatal heart attacks even for people who do not have the conditions normally associated with cardiovascular disease. A recent study published in April 2018 in the journal JAMA Cardiology [[7]](https://www.ncbi.nlm.nih.gov/pubmed/29490333) concluded that adults between ages 40 and 59 who are overweight or obese have a significantly increased risk (ranging from 21 to 85 percent higher) of developing cardiovascular disease as compared with their normal weight peers. Individuals who are overweight, defined as having a body mass index (BMI) between 25 and 29.9, or are obese (a BMI of 30 or higher), also have a much greater risk of developing cardiovascular disease at a younger age. The research showed that individuals who are obese had a shorter lifespan.
# [[8]](https://www.safefood.eu/SafeFood/media/SafeFoodLibrary/Documents/Professional/Nutrition/Adult-and-children-obesity-trends-ROI.pdf)

# %% [markdown]
# ## References
# - [Numpy official manual](https://docs.scipy.org/doc/numpy/index.html)
# - [1] [Mayo Clinic](https://www.mayoclinic.org/diseases-conditions/heart-attack/symptoms-causes/syc-20373106)
# - [2] [Harvard.edu](https://www.health.harvard.edu/heart-health/the-heart-attack-gender-gap)
# - [3] [British Heart Foundation](https://www.bhf.org.uk/informationsupport/risk-factors/family-history)
# - [4] [HSE](https://www.hse.ie/eng/health/az/c/coronary-heart-disease/)
# - [5] [CSO](https://www.cso.ie/en/releasesandpublications/ep/p-cpr/censusofpopulation2016-preliminaryresults/)
# - [6] [www.health.gov.ie](https://health.gov.ie/healthy-ireland/tobacco/smoking-prevalence-rates/)
# - [7] [www.ncbi.nlm.nih.gov](https://www.ncbi.nlm.nih.gov/pubmed/29490333)
# - [8] [www.safefood.eu](https://www.safefood.eu/SafeFood/media/SafeFoodLibrary/Documents/Professional/Nutrition/Adult-and-children-obesity-trends-ROI.pdf)
# - https://www.health.com/health/gallery/0,,20538581,00.html?slide=121137#121137

# %%
finalDS = pd.DataFrame({'age': age, 'gender': gender, 'Family history': fHist, 'Blood cholesterol': bloodCholNew, 'Tobacco consumption': smokers})
sns.pairplot(finalDS, hue="gender")
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
