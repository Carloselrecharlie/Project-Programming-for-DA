# %% [markdown]
# ### By Carlos Montes
#
# December 2018
#
# In this notebook I am going to look at a real phenomenon of my choice: a health study with a sample of population related to heart disease. A heart attack is usually caused by the buildup of plaque in the coronary arteries. The plaque builds up over time to eventually slow or completely block blood flow to the heart muscle. What matters now is the variables that condition the appearance of this health issue. It's worth mentioning that there may not be a most definitive one by itself, it seems to be just a question of balance between themselves. Anyways they are approximately graded from greater to lesser likelihood of importance.
#
# For the purpose of this exercise I will synthesise a data set with the values of all the risk factor which affect the heart attack. Half of the samples represent males and the other half woman being 400 in total.
#
# ## 1) Age
# As we get older, our risk of a heart attack goes up. Men age 45 or older and women age 55 or older are more likely to have a heart attack than are younger men and women [[1]](https://www.mayoclinic.org/diseases-conditions/heart-attack/symptoms-causes/syc-20373106) This is a discrete numerical variable and for the synthetised data set I am going to generate a sample of 400 people. The age will be presented in years with integer values and following a uniform distribution to garantee that all the age ranges will be equally represented.

# %%
import numpy as np
age = np.random.randint(20,85,size=400)
age
# Out:
# array([70, 24, 32, 84, 26, 62, 47, 46, 24, 20, 28, 79, 44, 82, 48, 22, 26,
#        69, 31, 55, 38, 59, 77, 41, 25, 74, 23, 35, 53, 82, 70, 29, 32, 69,
#        76, 53, 22, 52, 67, 61, 71, 39, 50, 73, 26, 57, 76, 71, 48, 45, 72,
#        52, 56, 81, 42, 37, 33, 34, 69, 30, 62, 65, 76, 57, 52, 24, 68, 45,
#        56, 50, 79, 56, 21, 70, 26, 38, 20, 82, 54, 78, 83, 55, 80, 68, 72,
#        60, 84, 27, 24, 71, 20, 47, 39, 44, 58, 35, 49, 28, 33, 79, 66, 26,
#        83, 62, 43, 33, 70, 31, 43, 60, 77, 78, 51, 28, 28, 34, 81, 84, 80,
#        40, 46, 20, 71, 33, 70, 30, 67, 26, 63, 70, 44, 53, 67, 24, 74, 22,
#        78, 53, 77, 45, 44, 21, 47, 70, 75, 71, 66, 64, 74, 43, 24, 75, 75,
#        31, 63, 58, 49, 33, 52, 32, 72, 21, 79, 53, 36, 75, 26, 42, 38, 55,
#        22, 34, 34, 47, 75, 84, 20, 31, 60, 77, 59, 48, 78, 62, 46, 36, 40,
#        65, 84, 41, 34, 36, 76, 77, 37, 73, 60, 63, 20, 61, 41, 69, 66, 51,
#        69, 60, 72, 24, 80, 59, 60, 27, 42, 43, 76, 20, 83, 42, 60, 30, 74,
#        37, 48, 54, 77, 72, 25, 32, 68, 25, 48, 41, 53, 56, 81, 65, 64, 72,
#        71, 66, 42, 35, 81, 77, 60, 72, 26, 84, 24, 83, 76, 22, 48, 77, 27,
#        21, 54, 60, 26, 20, 66, 34, 33, 49, 63, 34, 40, 46, 49, 32, 78, 64,
#        40, 79, 72, 39, 77, 72, 59, 70, 74, 70, 47, 63, 44, 47, 42, 58, 73,
#        49, 60, 48, 62, 31, 40, 23, 49, 31, 30, 42, 74, 24, 51, 73, 71, 47,
#        76, 74, 21, 50, 49, 84, 69, 58, 67, 53, 44, 61, 31, 57, 25, 53, 32,
#        23, 34, 53, 27, 49, 66, 38, 29, 53, 55, 25, 32, 49, 53, 70, 31, 58,
#        38, 79, 40, 43, 70, 75, 29, 30, 72, 27, 47, 73, 45, 54, 53, 71, 80,
#        58, 80, 61, 62, 51, 74, 60, 36, 29, 71, 82, 43, 65, 62, 78, 41, 66,
#        47, 47, 25, 40, 51, 40, 61, 38, 63, 42, 78, 83, 20, 52, 35, 71, 47,
#        65, 30, 60, 21, 81, 74, 60, 32, 41])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.hist(age)
plt.show()

# %% [markdown]
# ## 2) Gender
# Men face a greater risk of heart disease than women. On average, a first heart attack strikes men at age 65. For women, the average age of a first heart attack is 72 [[2]](https://www.health.harvard.edu/heart-health/the-heart-attack-gender-gap). This is non-numerical parameter -a string- which follows a Bernoulli distribution since there are just 2 possible outcomes (man and woman) being one of them more likely to occur (men).

# %%
possible_genders = ['male','female']
gender =  [np.random.choice(possible_genders) for i in range(400)]
gender
# Out:
# ['male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male']

# %%
plt.hist(gender)
plt.show()

# %% [markdown]
# ## 3) Family history
# Having a family history of cardiovascular disease increases the risk of developing cardiovascular diseases such as heart attacks. Genes can pass on the risk of cardiovascular disease, and they can also be responsible for passing on other conditions such as high blood pressure or high cholesterol levels [[3]](https://www.bhf.org.uk/informationsupport/risk-factors/family-history).
#
# For this excercise I will consider just 2 possible outcomes, the existance of a family history as 'Yes' or its absence as 'No'. This means that this variable holds strings however the likelyhood of both outcomes are not balanced. I could try to roughly estimate this by considering some facts from the Irish population like:
#
# - Around 10.000 people die every year for cardiovascular disorders [[4]](https://www.hse.ie/eng/health/az/c/coronary-heart-disease/)
# - The population in 2016 was nearly 4.800.000 according to CSO [[5]](https://www.cso.ie/en/releasesandpublications/ep/p-cpr/censusofpopulation2016-preliminaryresults/)
#
# But that would lead to a different project so for the puropose of this test the following figure doesn't need to be representative, it just means the difference in probability of every ocurrence. Then let's just say that a 30% of the people in Ireland has relatives who have had cardiovascular issues including all ranges of severity. Then the likelyhood of having a family history is 30%, and therefore the probability of not having a family history is 70%

# %%
possible_fHist = ['Yes','No']
fHist = np.random.choice(possible_fHist, 400, p=[0.3, 0.7])
plt.hist(fHist)
plt.show()

# %% [markdown]
# <img style="float: right;" src="https://www.sec.gov/Archives/edgar/data/12239/000110465912018448/g72481mmi005.jpg" alt="LDL cholesterol level" width="450" />
#
# ## 4) Blood Cholesterol
#
# LDL cholesterol travels from the liver through the arteries to other parts of our body. LDL is called bad cholesterol because it sticks to the walls in our arteries making them narrow. The image on the right shows the ranges of blood LDL cholesterol:
#
# In order to force the data set to be more representative of reality I am going to align this variable with the other two variables *age* and *gender* according to the statement given at the top of this document in the "Age" section: *Men age 45 or older and women age 55 or older are more likely to have a heart attack than are younger men and women* [[1]](https://www.mayoclinic.org/diseases-conditions/heart-attack/symptoms-causes/syc-20373106). This way I will assign higher  levels of this bad cholesterol to men older than 44 and women older than 54 because they are more likely to have a heart attack.
#
# When it comes to this variable itself, it is numerical and depending on how specific the machine that processes the blood sample is, we could label it as discrete or continuous. This is, if it returns an integer, then it would be discrete but if the figure has several decimals, then we can take it as continuous.

# %% [markdown]
# ## 5) Smoking

# %% [markdown]
# ## References
# - [Numpy official manual](https://docs.scipy.org/doc/numpy/index.html)
# - [1] [Mayo Clinic](https://www.mayoclinic.org/diseases-conditions/heart-attack/symptoms-causes/syc-20373106)
# - [2] [Harvard.edu](https://www.health.harvard.edu/heart-health/the-heart-attack-gender-gap)
# - [3] [British Heart Foundation](https://www.bhf.org.uk/informationsupport/risk-factors/family-history)
# - [4] [HSE](https://www.hse.ie/eng/health/az/c/coronary-heart-disease/)
# - [5] [CSO](https://www.cso.ie/en/releasesandpublications/ep/p-cpr/censusofpopulation2016-preliminaryresults/)
# - https://www.health.com/health/gallery/0,,20538581,00.html?slide=121137#121137

# %%
import pandas as pd

# Create a table with the synthetised data set
df = pd.DataFrame({'age': age, 'gender': gender, 'Family history': fHist})
# Align the columns at the center with the style feature
df.style.set_properties(**{'text-align': 'center'})
# Out:
# <style  type="text/css" >
#     #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow0_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow0_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow0_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow1_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow1_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow1_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow2_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow2_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow2_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow3_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow3_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow3_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow4_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow4_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow4_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow5_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow5_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow5_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow6_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow6_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow6_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow7_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow7_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow7_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow8_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow8_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow8_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow9_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow9_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow9_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow10_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow10_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow10_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow11_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow11_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow11_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow12_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow12_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow12_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow13_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow13_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow13_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow14_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow14_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow14_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow15_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow15_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow15_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow16_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow16_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow16_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow17_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow17_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow17_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow18_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow18_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow18_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow19_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow19_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow19_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow20_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow20_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow20_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow21_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow21_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow21_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow22_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow22_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow22_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow23_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow23_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow23_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow24_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow24_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow24_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow25_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow25_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow25_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow26_col0 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow26_col1 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow26_col2 {
#             text-align:  center;
#         }    #T_e0e39ce8_f823_11e8_9fe7_fc3fdb5c44bdrow27_col0 {
